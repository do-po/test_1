# %%
import pandas as pd
import folium
import json

# 서울시 스타벅스 매장 목록 데이터 불러오기
seoul_starbucks = pd.read_excel('./files/seoul_starbucks_list.xlsx')
seoul_starbucks.head()
# Out:
#        매장명         위도          경도         매장타입                          주소  \
# 0  역삼아레나빌딩  37.501087  127.043069  pin_general     서울특별시 강남구 언주로 425 (역삼동)
# 1   논현역사거리  37.510178  127.022223  pin_general    서울특별시 강남구 강남대로 538 (논현동)
# 2  신사역성일빌딩  37.513931  127.020606  pin_general    서울특별시 강남구 강남대로 584 (논현동)
# 3   국기원사거리  37.499517  127.031495  pin_general    서울특별시 강남구 테헤란로 125 (역삼동)
# 4   대치재경빌딩  37.494668  127.062583  pin_general  서울특별시 강남구 남부순환로 2947 (대치동)
#
#         전화번호 시군구명
# 0  1522-3232  강남구
# 1  1522-3232  강남구
# 2  1522-3232  강남구
# 3  1522-3232  강남구
# 4  1522-3232  강남구

# %%
# folium을 이용한 지도 생성
starbucks_map = folium.Map(
    location=[37.573050, 126.979189],
    zoom_start=11
)
starbucks_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9cc73355307e52c816be236925c7d536 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9cc73355307e52c816be236925c7d536&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9cc73355307e52c816be236925c7d536 = L.map(
#                 &quot;map_9cc73355307e52c816be236925c7d536&quot;,
#                 {
#                     center: [37.57305, 126.979189],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce25a624102429128da959ceb9326806 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ce25a624102429128da959ceb9326806.addTo(map_9cc73355307e52c816be236925c7d536);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 스타벅스 매장 위치를 나타내는 서클 마커 그리기
for idx in seoul_starbucks.index:
    lat = seoul_starbucks.loc[idx, '위도']
    lng = seoul_starbucks.loc[idx, '경도']
    
    folium.CircleMarker(
        location=[lat, lng],
        fill = True,
        fill_color='green',
        fill_opacity=1, # 투명도
        color='yellow',
        weight=1, # 색 채우겠다
        radius=3
    ).add_to(starbucks_map)

starbucks_map

# %%
seoul_starbucks['매장타입'].value_counts()
# Out:
# 매장타입
# pin_general      551
# pin_reserve       34
# pin_generalDT     23
# pin_generalWT      2
# Name: count, dtype: int64

# %%
seoul_starbucks.index
# Out:
# RangeIndex(start=0, stop=610, step=1)

# %%
# 스타벅스 매장 위치를 나타내는 서클 마커 그리기

for idx in seoul_starbucks.index:
    lat = seoul_starbucks.loc[idx, '위도']
    lng = seoul_starbucks.loc[idx, '경도']

    if seoul_starbucks.loc[idx, '매장타입'] == 'pin_general':
        colors = 'grey'
        size = 3
    elif seoul_starbucks.loc[idx, '매장타입'] == 'pin_reserve':
        colors = 'blue'
        size = 10
    elif seoul_starbucks.loc[idx, '매장타입'] == 'pin_generalDT':
        colors = 'red'
        size = 7
    elif seoul_starbucks.loc[idx, '매장타입'] == 'pin_generalWT':
        colors = 'green'
        size = 7
    else:
        colors = 'purple'
        size = 5

    folium.CircleMarker(
        location=[lat, lng],
        fill = True,

        fill_color=f'{colors}',
        fill_opacity=1, # 투명도
        color=f'{colors}',
        weight=1, # 색 채우겠다
        radius=f'{size}'
    ).add_to(starbucks_map)

starbucks_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9cc73355307e52c816be236925c7d536 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9cc73355307e52c816be236925c7d536&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9cc73355307e52c816be236925c7d536 = L.map(
#                 &quot;map_9cc73355307e52c816be236925c7d536&quot;,
#                 {
#                     center: [37.57305, 126.979189],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce25a624102429128da959ceb9326806 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ce25a624102429128da959ceb9326806.addTo(map_9cc73355307e52c816be236925c7d536);
#
#
#             tile_layer_ce25a624102429128da959ceb9326806.addTo(map_9cc73355307e52c816be236925c7d536);
#
#
#             var circle_marker_5adbf4454aacd81c1f5405f169497dbf = L.circleMarker(
#                 [37.501087, 127.043069],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;grey&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;grey&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: &quot;3&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_9cc73355307e52c816be236925c7d536);
#
#
#             var circle_marker_b022ae0759138c9ee6ce1796283fc00b = L.circleMarker(
#                 [37.510178, 127.022223],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;grey&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;grey&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: &quot;3&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_9cc73355307e52c816be236925c7d536);
#
#
#             var circle_marker_adf7d6898b06c9a0893b66914dfe9496 = L.circleMarker(
#                 [37.5139309, 127.0206057],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;grey&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;grey&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: &quot;3&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_9cc73355307e52c816be236925c7d536);
#
#
#             var circle_marker_ca454d7115c43e15f8df03099871c629 = L.circleMarker(
#                 [37.499517, 127.031495],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;grey&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;grey&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: &quot;3&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_9cc73355307e52c816be236925c7d536);
#
#
#             var circle_marker_dc4055978181ac326f45845f51df3074 = L.circleMarker(
#                 [37.494668, 127.062583],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;grey&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;grey&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: &quot;3&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_9cc73355307e52c816be236925c7d536);
#
#
#             var circle_marker_6cdd1340b6129c4d218912dea2c3fb52 = L.circleMarker(
#                 [37.515, 127.063196],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;grey&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;grey&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: &quot;3&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_9cc73355307e52c816be236925c7d536);

# %%
seoul_starbucks.loc[0, '위도']
# Out:
# 37.501087

# %%
seoul_starbucks.loc[1, '매장명']
# Out:
# '논현역사거리'

# %% [markdown]
# ### 01-2 시군구별 스타벅스 매장 수 시각화

# %%
# 서울시 시군구별 통계 데이터 불러오기

seoul_sgg_stat = pd.read_excel('./files/seoul_sgg_stat.xlsx')
seoul_sgg_stat
# Out:
#     시군구코드  시군구명         위도          경도    종사자수    사업체수
# 0   11320   도봉구  37.665861  127.031767   79097   25391
# 1   11380   은평구  37.617612  126.922700  109031   36509
# 2   11230  동대문구  37.583801  127.050700  146383   42813
# 3   11590   동작구  37.496504  126.944307  109281   27915
# 4   11545   금천구  37.460097  126.900155  255449   47964
# 5   11530   구로구  37.495486  126.858121  240689   52791
# 6   11110   종로구  37.599100  126.986149  275063   48361
# 7   11305   강북구  37.646995  127.014716   80222   26385
# 8   11260   중랑구  37.595379  127.093967  113144   39310
# 9   11680   강남구  37.495985  127.066409  801419  110007
# 10  11500   강서구  37.565762  126.822656  290473   58806
# 11  11140    중구  37.557945  126.994190  386564   70308
# 12  11740   강동구  37.549208  127.146482  157465   41660
# 13  11215   광진구  37.548144  127.085753  129707   33706
# 14  11440   마포구  37.562291  126.908780  279788   56782
# 15  11650   서초구  37.476953  127.037810  487976   71958
# 16  11290   성북구  37.606991  127.023218  124004   34712
# 17  11350   노원구  37.655264  127.077120  133398   37909
# 18  11710   송파구  37.504853  127.114482  400781   74531
# 19  11410  서대문구  37.582037  126.935666  118256   28522
# 20  11470   양천구  37.527062  126.856153  133776   37929
# 21  11560  영등포구  37.520641  126.913924  435017   74562
# 22  11620   관악구  37.465399  126.943807  128417   37915
# 23  11200   성동구  37.550675  127.040962  203221   41665
# 24  11170   용산구  37.531101  126.981074  152605   29680
