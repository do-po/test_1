# %% [markdown]
# # 데이터 로드

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

plt.style.use("ggplot")
plt.rc('font', family='NanumGothic')

# %%
customer = pd.read_csv('./data_in/customers.csv')
location = pd.read_csv('./data_in/locations.csv')
order_items = pd.read_csv('./data_in/order_items.csv')
orders = pd.read_csv('./data_in/orders.csv')
payments = pd.read_csv('./data_in/payments.csv')
product = pd.read_csv('./data_in/products.csv')
review = pd.read_csv('./data_in/reviews.csv')
seller = pd.read_csv('./data_in/sellers.csv')

# %%
# order_items, orders, sellers
orders.columns
# Out:
# Index(['Order_id', 'Customer_id', 'Order_status', 'Order_purchase_timestamp',
#        'Order_delivered_carrier_date', 'Order_delivered_customer_date',
#        'Order_estimated_delivery_date'],
#       dtype='object')

# %%
location
# Out:
#          Geolocation_zipcode_prefix  Geolocation_lat  Geolocation_lng  \
# 0                              1037       -23.545621       -46.639292
# 1                              1046       -23.546081       -46.644820
# 2                              1046       -23.546129       -46.642951
# 3                              1041       -23.544392       -46.639499
# 4                              1035       -23.541578       -46.641607
# ...                             ...              ...              ...
# 1000158                       99950       -28.068639       -52.010705
# 1000159                       99900       -27.877125       -52.224882
# 1000160                       99950       -28.071855       -52.014716
# 1000161                       99980       -28.388932       -51.846871
# 1000162                       99950       -28.070104       -52.018658
#
#         Geolocation_city Geolocation_state
# 0              sao paulo                SP
# ...

# %%
order_items
# Out:
#            Order_id  Order_item_id     Product_id    Seller_id   Price  \
# 0       ORDER_75477              1  PRODUCT_23128  SELLER_0452   58.90
# 1       ORDER_63604              1  PRODUCT_24351  SELLER_0414  239.90
# 2       ORDER_05566              1  PRODUCT_20226  SELLER_1637  199.00
# 3       ORDER_04632              1  PRODUCT_07878  SELLER_1445  199.90
# 4       ORDER_61452              1  PRODUCT_03505  SELLER_0581   21.90
# ...             ...            ...            ...          ...     ...
# 100552  ORDER_70405              1  PRODUCT_04209  SELLER_2078  299.99
# 100553  ORDER_62069              1  PRODUCT_08229  SELLER_1593  350.00
# 100554  ORDER_46632              1  PRODUCT_21462  SELLER_0528   99.90
# 100555  ORDER_52966              1  PRODUCT_19978  SELLER_2563   55.99
# 100556  ORDER_52855              1  PRODUCT_05243  SELLER_1844   43.00
#
#         Freight_value
# 0               13.29
# 1               19.93
# 2               17.87
# ...

# %%
payments
# Out:
#           Order_id  Payment_sequential Payment_type  Payment_installments  \
# 0      ORDER_66617                   1  credit_card                     8
# 1      ORDER_86954                   1  credit_card                     1
# 2      ORDER_38852                   1  credit_card                     1
# 3      ORDER_57443                   1  credit_card                     8
# 4      ORDER_11244                   1  credit_card                     2
# ...            ...                 ...          ...                   ...
# 91966  ORDER_46197                   1  credit_card                     1
# 91967  ORDER_37509                   1  credit_card                     2
# 91968  ORDER_85760                   1       boleto                     1
# 91969  ORDER_35237                   1  credit_card                     2
# 91970  ORDER_61019                   1       boleto                     1
#
#        Payment_value
# 0              99.33
# 1              24.39
# ...

# %%
seller
# Out:
#         Seller_id  Seller_zipcode_prefix        Seller_city Seller_state
# 0     SELLER_0000                  13023           campinas           SP
# 1     SELLER_0001                  13844         mogi guacu           SP
# 2     SELLER_0002                  12914  braganca paulista           SP
# 3     SELLER_0003                  20920     rio de janeiro           RJ
# 4     SELLER_0004                  55325             brejao           PE
# ...           ...                    ...                ...          ...
# 2758  SELLER_2758                  87111            sarandi           PR
# 2759  SELLER_2759                  88137            palhoca           SC
# 2760  SELLER_2760                   4650          sao paulo           SP
# 2761  SELLER_2761                  96080            pelotas           RS
# 2762  SELLER_2762                  12051            taubate           SP
#
# [2763 rows x 4 columns]

# %%
product
# Out:
#           Product_id        Product_category_name Product_weight_g  \
# 0      PRODUCT_00000                    perfumery            225.0
# 1      PRODUCT_00001                         arts           1000.0
# 2      PRODUCT_00002               sports_leisure            154.0
# 3      PRODUCT_00003               home_utilities            625.0
# 4      PRODUCT_00004          musical_instruments            200.0
# ...              ...                          ...              ...
# 29466  PRODUCT_29466              furniture_decor          12300.0
# 29467  PRODUCT_29467  construction_tools_lighting           1700.0
# 29468  PRODUCT_29468               bed_bath_table           1400.0
# 29469  PRODUCT_29469        computers_accessories            700.0
# 29470  PRODUCT_29470               bed_bath_table           2083.0
#
#       Product_length_cm Product_height_cm Product_width_cm
# 0                  16.0              10.0             14.0
# ...

# %%
review
# Out:
#           Review_id     Order_id  Review_score Review_creation_date  \
# 0      REVIEW_00000  ORDER_01674             4  2019-01-18 00:00:00
# 1      REVIEW_00001  ORDER_80140             5  2019-03-10 00:00:00
# 2      REVIEW_00002  ORDER_69816             5  2019-02-17 00:00:00
# 3      REVIEW_00003  ORDER_24398             5  2018-04-21 00:00:00
# 4      REVIEW_00004  ORDER_70366             5  2019-03-01 00:00:00
# ...             ...          ...           ...                  ...
# 87868  REVIEW_87298  ORDER_58840             5  2019-07-07 00:00:00
# 87869  REVIEW_87299  ORDER_75162             5  2018-12-09 00:00:00
# 87870  REVIEW_87300  ORDER_08690             5  2019-03-22 00:00:00
# 87871  REVIEW_87301  ORDER_25681             4  2019-07-01 00:00:00
# 87872  REVIEW_87302  ORDER_45326             1  2018-07-03 00:00:00
#
#       Review_answer_timestamp
# 0         2019-01-18 21:46:59
# 1         2019-03-11 03:05:13
# 2         2019-02-18 14:36:24
# ...

# %%
total = pd.merge(order_items, orders, how= 'left', on= 'Order_id')

# %%
total = pd.merge(total, seller, how= 'left', on= 'Seller_id')

# %%
total = pd.merge(total, product, how= 'left', on= 'Product_id')

# %%
total.to_csv('./data_in/total_df.csv', index= False)

# %%
total_df = pd.read_csv('./data_in/total_df.csv')
# Out:
# C:\Users\SeonB2\AppData\Local\Temp\ipykernel_31212\3184106167.py:1: DtypeWarning: Columns (16,17,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   total_df = pd.read_csv('./data_in/total_df.csv')

# %%
total_df['Revenue'] = total_df['Price'] * total_df['Order_item_id']

# %%
total_df.to_csv('./data_in/total_df.csv',index= False)

# %%
total_df['Revenue'] = total_df['Revenue'].map(
    lambda x: pd.to_numeric(x)
)

# %%
total_df['Revenue']
# Out:
# 0          58.90
# 1         239.90
# 2         199.00
# 3         199.90
# 4          21.90
#            ...
# 100552    299.99
# 100553    350.00
# 100554     99.90
# 100555     55.99
# 100556     43.00
# Name: Revenue, Length: 100557, dtype: float64

# %%
total_df.drop('Unnamed: 0', axis= 1, inplace= True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 total_df.drop('Unnamed: 0', axis= 1, inplace= True)
#
# File c:\Users\SeonB2\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
#    5574         inplace=inplace,
# ...

# %%
total_df.reset_index(drop= True)
# Out:
#            Order_id  Order_item_id     Product_id    Seller_id   Price  \
# 0       ORDER_75477              1  PRODUCT_23128  SELLER_0452   58.90
# 1       ORDER_63604              1  PRODUCT_24351  SELLER_0414  239.90
# 2       ORDER_05566              1  PRODUCT_20226  SELLER_1637  199.00
# 3       ORDER_04632              1  PRODUCT_07878  SELLER_1445  199.90
# 4       ORDER_61452              1  PRODUCT_03505  SELLER_0581   21.90
# ...             ...            ...            ...          ...     ...
# 100552  ORDER_70405              1  PRODUCT_04209  SELLER_2078  299.99
# 100553  ORDER_62069              1  PRODUCT_08229  SELLER_1593  350.00
# 100554  ORDER_46632              1  PRODUCT_21462  SELLER_0528   99.90
# 100555  ORDER_52966              1  PRODUCT_19978  SELLER_2563   55.99
# 100556  ORDER_52855              1  PRODUCT_05243  SELLER_1844   43.00
#
#         Freight_value     Customer_id Order_status Order_purchase_timestamp  \
# ...

# %%
customer
# Out:
#           Customer_id     Customer_unique_id  Customer_zipcode_prefix  \
# 0      CUSTOMER_00000  CUSTOMER_Unique_00000                    14409
# 1      CUSTOMER_00001  CUSTOMER_Unique_00001                     9790
# 2      CUSTOMER_00002  CUSTOMER_Unique_00002                     1151
# 3      CUSTOMER_00003  CUSTOMER_Unique_00003                     8775
# 4      CUSTOMER_00004  CUSTOMER_Unique_00004                    89254
# ...               ...                    ...                      ...
# 87950  CUSTOMER_88083  CUSTOMER_Unique_85234                     3937
# 87951  CUSTOMER_88084  CUSTOMER_Unique_85235                     6764
# 87952  CUSTOMER_88085  CUSTOMER_Unique_85236                    60115
# 87953  CUSTOMER_88086  CUSTOMER_Unique_85237                    92120
# 87954  CUSTOMER_88087  CUSTOMER_Unique_85238                     6703
#
#                Customer_city Customer_state
# 0                     franca             SP
# ...

# %%
total_df.to_csv('./data_in/total_df.csv', index= False)

# %%
payments
# Out:
#           Order_id  Payment_sequential Payment_type  Payment_installments  \
# 0      ORDER_66617                   1  credit_card                     8
# 1      ORDER_86954                   1  credit_card                     1
# 2      ORDER_38852                   1  credit_card                     1
# 3      ORDER_57443                   1  credit_card                     8
# 4      ORDER_11244                   1  credit_card                     2
# ...            ...                 ...          ...                   ...
# 91966  ORDER_46197                   1  credit_card                     1
# 91967  ORDER_37509                   1  credit_card                     2
# 91968  ORDER_85760                   1       boleto                     1
# 91969  ORDER_35237                   1  credit_card                     2
# 91970  ORDER_61019                   1       boleto                     1
#
#        Payment_value
# 0              99.33
# 1              24.39
# ...

# %%
total_df = pd.merge(total_df, payments, how= 'left', on= 'Order_id')

# %%
total_df = pd.merge(total_df, customer, how= 'left', on = 'Customer_id')

# %%
review
# Out:
#           Review_id     Order_id  Review_score Review_creation_date  \
# 0      REVIEW_00000  ORDER_01674             4  2019-01-18 00:00:00
# 1      REVIEW_00001  ORDER_80140             5  2019-03-10 00:00:00
# 2      REVIEW_00002  ORDER_69816             5  2019-02-17 00:00:00
# 3      REVIEW_00003  ORDER_24398             5  2018-04-21 00:00:00
# 4      REVIEW_00004  ORDER_70366             5  2019-03-01 00:00:00
# ...             ...          ...           ...                  ...
# 87868  REVIEW_87298  ORDER_58840             5  2019-07-07 00:00:00
# 87869  REVIEW_87299  ORDER_75162             5  2018-12-09 00:00:00
# 87870  REVIEW_87300  ORDER_08690             5  2019-03-22 00:00:00
# 87871  REVIEW_87301  ORDER_25681             4  2019-07-01 00:00:00
# 87872  REVIEW_87302  ORDER_45326             1  2018-07-03 00:00:00
#
#       Review_answer_timestamp
# 0         2019-01-18 21:46:59
# 1         2019-03-11 03:05:13
# 2         2019-02-18 14:36:24
# ...

# %%
# total_df = pd.merge(total_df, review, how= 'left', on= 'Order_id')

# %%
total_df.to_csv('./data_in/total_df.csv', index= False)

# %%
location
# Out:
#          Geolocation_zipcode_prefix  Geolocation_lat  Geolocation_lng  \
# 0                              1037       -23.545621       -46.639292
# 1                              1046       -23.546081       -46.644820
# 2                              1046       -23.546129       -46.642951
# 3                              1041       -23.544392       -46.639499
# 4                              1035       -23.541578       -46.641607
# ...                             ...              ...              ...
# 1000158                       99950       -28.068639       -52.010705
# 1000159                       99900       -27.877125       -52.224882
# 1000160                       99950       -28.071855       -52.014716
# 1000161                       99980       -28.388932       -51.846871
# 1000162                       99950       -28.070104       -52.018658
#
#         Geolocation_city Geolocation_state
# 0              sao paulo                SP
# ...

# %%
total_df['']

# %%
# 장기 고객 - customer_unique_id
# 판매자별 성과 분석 - seller_id
# 배송시간 비교 - order_estimated_delivery_date
# 할부사용 분석 - payment_installments
# 제품별 판매량 및 선호도 분석 - product_id
# 주문내 품목수 - order_item_id
# 고객 서비스 응답시간 - review_answer_timestamp
# 구매시간 분석 - order_purchase_timestamp

# %% [markdown]
# - 'Customer_unique_id' = 고객 고유 ID
# - 'Seller_id' = 판매자 고유 ID
# - 'Product_id' = 제품 고유 ID
# - 'Order_estimated_delivery_date' = 기대 배송 날짜
# - 'Order_delivered_customer_date' = 실제 배송 날짜
# - 'Order_purchase_timestamp' = 구매 시간
# - 'Review_answer_timestamp' = 리뷰 답변 시간
# - 'Review_creation_date' : 리뷰 생성 시간
# - 'Order_item_id' = 동일한 주문에 포함된 품목 수를 식별하는 일련 번호
# - 'Payment_installments' = 할부 횟수
# - 'Revenue' = 매출

# %%
columns_filter = ['Customer_unique_id', 'Seller_id', 'Product_id', 'Order_estimated_delivery_date', 'Order_delivered_customer_date', \
                  'Order_purchase_timestamp','Review_creation_date', 'Review_answer_timestamp', 'Order_item_id', 'Payment_installments', 'Revenue']

# %%
total_df[columns_filter].to_csv('./data_in/prep.csv', index= False)

# %%
prep = pd.read_csv('./data_in/prep.csv')

prep
# Out:
#            Customer_unique_id    Seller_id     Product_id  \
# 0       CUSTOMER_Unique_56776  SELLER_0452  PRODUCT_23128
# 1       CUSTOMER_Unique_29981  SELLER_0414  PRODUCT_24351
# 2       CUSTOMER_Unique_30575  SELLER_1637  PRODUCT_20226
# 3       CUSTOMER_Unique_06699  SELLER_1445  PRODUCT_07878
# 4       CUSTOMER_Unique_20225  SELLER_0581  PRODUCT_03505
# ...                       ...          ...            ...
# 105761  CUSTOMER_Unique_75913  SELLER_2078  PRODUCT_04209
# 105762  CUSTOMER_Unique_23429  SELLER_1593  PRODUCT_08229
# 105763  CUSTOMER_Unique_01324  SELLER_0528  PRODUCT_21462
# 105764  CUSTOMER_Unique_49218  SELLER_2563  PRODUCT_19978
# 105765  CUSTOMER_Unique_03405  SELLER_1844  PRODUCT_05243
#
#        Order_estimated_delivery_date Order_delivered_customer_date  \
# 0                         2018-09-29           2018-09-20 23:43:48
# 1                         2018-05-15           2018-05-12 16:04:24
# ...

# %%
prep['Order_purchase_timestamp'].map(
    lambda x : x.(format= '%Y%d%m')
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 prep['Order_purchase_timestamp'].map(
#       2     lambda x : x.dt.to_timestamp(format= '%Y%d%m')
#       3 )
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:4691, in Series.map(self, arg, na_action)
#    4611 def map(
#    4612     self,
#    4613     arg: Callable | Mapping | Series,
#    4614     na_action: Literal["ignore"] | None = None,
#    4615 ) -> Series:
#    4616     """
#    4617     Map values of Series according to an input mapping or function.
#    4618
#    (...)
#    4689     dtype: object
#    4690     """
# -> 4691     new_values = self._map_values(arg, na_action=na_action)
#    4692     return self._constructor(new_values, index=self.index, copy=False).__finalize__(
#    4693         self, method="map"
#    4694     )
#
# ...

# %%
try_2 = pd.read_csv('./data_in/total_df.csv')

try_2
# Out:
# C:\Users\SeonB2\AppData\Local\Temp\ipykernel_31212\949764392.py:1: DtypeWarning: Columns (16,17,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   try_2 = pd.read_csv('./data_in/total_df.csv')
#            Order_id  Order_item_id     Product_id    Seller_id   Price  \
# 0       ORDER_75477              1  PRODUCT_23128  SELLER_0452   58.90
# 1       ORDER_63604              1  PRODUCT_24351  SELLER_0414  239.90
# 2       ORDER_05566              1  PRODUCT_20226  SELLER_1637  199.00
# 3       ORDER_04632              1  PRODUCT_07878  SELLER_1445  199.90
# 4       ORDER_61452              1  PRODUCT_03505  SELLER_0581   21.90
# ...             ...            ...            ...          ...     ...
# 105761  ORDER_70405              1  PRODUCT_04209  SELLER_2078  299.99
# 105762  ORDER_62069              1  PRODUCT_08229  SELLER_1593  350.00
# 105763  ORDER_46632              1  PRODUCT_21462  SELLER_0528   99.90
# ...

# %%
filter_columns =['Review_id', 'Review_score', 'Review_creation_date', 'Review_answer_timestamp']

# %%
try_2[filter_columns]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\SeonB2\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 try_2[filter_columns]
#
# ...

# %%
total_df.isna().sum()
# Out:
# Order_id                         0
# Order_item_id                    0
# Product_id                       0
# Seller_id                        0
# Price                            0
# Freight_value                    0
# Customer_id                      0
# Order_status                     0
# Order_purchase_timestamp         0
# Order_delivered_carrier_date     0
# Order_delivered_customer_date    0
# Order_estimated_delivery_date    0
# Seller_zipcode_prefix            0
# Seller_city                      0
# Seller_state                     0
# Product_category_name            0
# Product_weight_g                 0
# Product_length_cm                0
# Product_height_cm                0
# Product_width_cm                 0
# Revenue                          0
# Payment_sequential               0
# Payment_type                     0
# Payment_installments             0
# Payment_value                    0
# Customer_unique_id               0
# Customer_zipcode_prefix          0
# ...
