# %%
import folium

# %%
# 서울 지도 만들기
seoul_map = folium.Map(location=[37.55,126.98], zoom_start=12)
# 지도를 HTML 파일로 저장하기
seoul_map.save('./seoul.html')

# %%
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5ffa3900abd13fb85dc10d41780ecc6c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5ffa3900abd13fb85dc10d41780ecc6c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5ffa3900abd13fb85dc10d41780ecc6c = L.map(
#                 &quot;map_5ffa3900abd13fb85dc10d41780ecc6c&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_872b37c7b31d56855207deef7030865f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_872b37c7b31d56855207deef7030865f.addTo(map_5ffa3900abd13fb85dc10d41780ecc6c);
#
#
#             tile_layer_872b37c7b31d56855207deef7030865f.addTo(map_5ffa3900abd13fb85dc10d41780ecc6c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from folium.map import Popup
import pandas as pd
import folium

# %%
df = pd.read_excel('./서울지역 대학교 위치.xlsx')

# %%
df
# Out:
#         Unnamed: 0         위도          경도
# 0     KAIST 서울캠퍼스   37.592573  127.046737
# 1            KC대학교  37.548345  126.854797
# 2     가톨릭대학교(성신교정)  37.585922  127.004328
# 3     가톨릭대학교(성의교정)  37.499623  127.006065
# 4         감리교신학대학교  37.567645  126.961610
# 5            건국대학교  37.540762  127.079343
# 6     경기대학교 서울캠퍼스   37.300485  127.035833
# 7     경희대학교 서울캠퍼스   37.596195  127.052544
# 8            고려대학교  33.847782 -117.977748
# 9            광운대학교  37.619496  127.059696
# 10           국민대학교  37.609641  126.997697
# 11         덕성여자대학교  37.651199  127.016160
# 12           동국대학교  37.557477  127.002052
# 13         동덕여자대학교  37.606320  127.041808
# 14    명지대학교 서울캠퍼스   37.580205  126.923445
# 15           삼육대학교  37.642952  127.105476
# 16    상명대학교 서울캠퍼스   37.602638  126.955252
# 17           서강대학교  37.550944  126.941002
# 18           서경대학교  37.615095  127.013111
# 19       서울과학기술대학교  37.631668  127.077481
# 20         서울교육대학교  37.489961  127.016412
# 21         서울기독대학교  37.600923  126.912382
# 22           서울대학교  37.459882  126.951905
# 23         서울시립대학교  37.583866  127.058777
# 24         서울여자대학교  37.628113  127.090457
# 25         서울한영대학교  37.496541  126.851262
# 26          성공회대학교  37.487232  126.825320
# 27  성균관대학교 서울캠퍼스    37.588227  126.993606
# 28         성신여자대학교  37.591310  127.022131
# 29           세종대학교  37.550260  127.073139
# 30         숙명여자대학교  37.546364  126.964831
# 31           숭실대학교  37.496311  126.957460
# 32           연세대학교  37.565784  126.938572
# 33          육군사관학교  37.623819  127.098878
# 34         이화여자대학교  37.564308  126.950179
# 35        장로회신학대학교  37.550511  127.103458
# 36    중앙대학교 서울캠퍼스   37.505088  126.957101
# 37           총신대학교  37.488623  126.966817
# 38         추계예술대학교  37.562452  126.953417
# 39       한국방송통신대학교  37.578613  127.003291
# 40         한국성서대학교  37.648749  127.064320
# 41        한국예술종합학교  37.604997  127.056740
# 42        한국외국어대학교  37.597319  127.057843
# 43         한국체육대학교  37.519627  127.130984
# 44           한성대학교  37.581785  127.010369
# 45           한양대학교  37.557232  127.045322
# 46           홍익대학교  37.551464  126.925011

# %%
seoul_map = folium.Map(location = [37.55,126.98], zoom_start = 12)

# %%
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ee44606614655d76b62cb6bf57f2b8c6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ee44606614655d76b62cb6bf57f2b8c6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ee44606614655d76b62cb6bf57f2b8c6 = L.map(
#                 &quot;map_ee44606614655d76b62cb6bf57f2b8c6&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_840a4bd8d0d4c6e8a128279e06dcd11a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_840a4bd8d0d4c6e8a128279e06dcd11a.addTo(map_ee44606614655d76b62cb6bf57f2b8c6);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df
# Out:
#         Unnamed: 0         위도          경도
# 0     KAIST 서울캠퍼스   37.592573  127.046737
# 1            KC대학교  37.548345  126.854797
# 2     가톨릭대학교(성신교정)  37.585922  127.004328
# 3     가톨릭대학교(성의교정)  37.499623  127.006065
# 4         감리교신학대학교  37.567645  126.961610
# 5            건국대학교  37.540762  127.079343
# 6     경기대학교 서울캠퍼스   37.300485  127.035833
# 7     경희대학교 서울캠퍼스   37.596195  127.052544
# 8            고려대학교  33.847782 -117.977748
# 9            광운대학교  37.619496  127.059696
# 10           국민대학교  37.609641  126.997697
# 11         덕성여자대학교  37.651199  127.016160
# 12           동국대학교  37.557477  127.002052
# 13         동덕여자대학교  37.606320  127.041808
# 14    명지대학교 서울캠퍼스   37.580205  126.923445
# 15           삼육대학교  37.642952  127.105476
# 16    상명대학교 서울캠퍼스   37.602638  126.955252
# 17           서강대학교  37.550944  126.941002
# 18           서경대학교  37.615095  127.013111
# 19       서울과학기술대학교  37.631668  127.077481
# 20         서울교육대학교  37.489961  127.016412
# 21         서울기독대학교  37.600923  126.912382
# 22           서울대학교  37.459882  126.951905
# 23         서울시립대학교  37.583866  127.058777
# 24         서울여자대학교  37.628113  127.090457
# 25         서울한영대학교  37.496541  126.851262
# 26          성공회대학교  37.487232  126.825320
# 27  성균관대학교 서울캠퍼스    37.588227  126.993606
# 28         성신여자대학교  37.591310  127.022131
# 29           세종대학교  37.550260  127.073139
# 30         숙명여자대학교  37.546364  126.964831
# 31           숭실대학교  37.496311  126.957460
# 32           연세대학교  37.565784  126.938572
# 33          육군사관학교  37.623819  127.098878
# 34         이화여자대학교  37.564308  126.950179
# 35        장로회신학대학교  37.550511  127.103458
# 36    중앙대학교 서울캠퍼스   37.505088  126.957101
# 37           총신대학교  37.488623  126.966817
# 38         추계예술대학교  37.562452  126.953417
# 39       한국방송통신대학교  37.578613  127.003291
# 40         한국성서대학교  37.648749  127.064320
# 41        한국예술종합학교  37.604997  127.056740
# 42        한국외국어대학교  37.597319  127.057843
# 43         한국체육대학교  37.519627  127.130984
# 44           한성대학교  37.581785  127.010369
# 45           한양대학교  37.557232  127.045322
# 46           홍익대학교  37.551464  126.925011

# %%
df.set_index('Unnamed: 0', inplace = True)

# %%
# 대학교 위치정보를 Marker로 표시
for name, lat, lng in zip(df.index, df.위도, df.경도): # zip == record(행의 단위)를 불러올 수 있는 함수
    iframe = folium.IFrame(name, width = 230, height = 50) # popup 객체 속의 IFrame의 사이즈 변경 (popup 레이어 위의 객체 저장 레이어)
    popup = folium.Popup(iframe, max_width = 300) # 선택했을 때 뒷 배경이 클릭되지 않도록 배경지를 만들어 주는 레이어
    folium.Marker([lat, lng], popup=popup).add_to(seoul_map) # [위도, 경도], index로 마커 팝업

seoul_map.save('./seoul.colleges.html')
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ee44606614655d76b62cb6bf57f2b8c6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ee44606614655d76b62cb6bf57f2b8c6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ee44606614655d76b62cb6bf57f2b8c6 = L.map(
#                 &quot;map_ee44606614655d76b62cb6bf57f2b8c6&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_840a4bd8d0d4c6e8a128279e06dcd11a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_840a4bd8d0d4c6e8a128279e06dcd11a.addTo(map_ee44606614655d76b62cb6bf57f2b8c6);
#
#
#             tile_layer_840a4bd8d0d4c6e8a128279e06dcd11a.addTo(map_ee44606614655d76b62cb6bf57f2b8c6);
#
#
#             var marker_0a00b6df1ef5eff57cbf8a4342e47cee = L.marker(
#                 [37.592573, 127.046737],
#                 {}
#             ).addTo(map_ee44606614655d76b62cb6bf57f2b8c6);
#
#
#         var popup_6e9770f0bb2bc34d7e13b04ecf346cfd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_542d708fc5bc76a9a708e294c5d316bc = $(`&lt;div id=&quot;html_542d708fc5bc76a9a708e294c5d316bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0&lt;/div&gt;`)[0];
#                 popup_6e9770f0bb2bc34d7e13b04ecf346cfd.setContent(html_542d708fc5bc76a9a708e294c5d316bc);
#
#
#
#         marker_0a00b6df1ef5eff57cbf8a4342e47cee.bindPopup(popup_6e9770f0bb2bc34d7e13b04ecf346cfd)
#         ;
#
#
#
#
#             var marker_f3b63964f30c813d9ddc72b730d07ae9 = L.marker(
#                 [37.5483449, 126.8547974],
#                 {}
#             ).addTo(map_ee44606614655d76b62cb6bf57f2b8c6);
#
#
#         var popup_47da073a66a8692e2e30cf7eca514c68 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fff1e02d8c581aea16e6e5fe29fdb6f7 = $(`&lt;div id=&quot;html_fff1e02d8c581aea16e6e5fe29fdb6f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1&lt;/div&gt;`)[0];
#                 popup_47da073a66a8692e2e30cf7eca514c68.setContent(html_fff1e02d8c581aea16e6e5fe29fdb6f7);
#
#
#
#         marker_f3b63964f30c813d9ddc72b730d07ae9.bindPopup(popup_47da073a66a8692e2e30cf7eca514c68)
#         ;
#
#
#
#
#             var marker_cca5e128857f3dd2d64182f230f40bfa = L.marker(
#                 [37.5859218, 127.0043275],
#                 {}
#             ).addTo(map_ee44606614655d76b62cb6bf57f2b8c6);
#
#
#         var popup_7249c4727b7f95a8bd9670a4cd6d75d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0409218194d9820e25fa573da225ab89 = $(`&lt;div id=&quot;html_0409218194d9820e25fa573da225ab89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2&lt;/div&gt;`)[0];
#                 popup_7249c4727b7f95a8bd9670a4cd6d75d8.setContent(html_0409218194d9820e25fa573da225ab89);
#
#
#
#         marker_cca5e128857f3dd2d64182f230f40bfa.bindPopup(popup_7249c4727b7f95a8bd9670a4cd6d75d8)
#         ;
#
#
#
#
#             var marker_9a472353d3ced6b54792bb02ab70905c = L.marker(
#                 [37.4996227, 127.0060653],
#                 {}
#             ).addTo(map_ee44606614655d76b62cb6bf57f2b8c6);
#
#
#         var popup_975280a7a689d58f26e9629ca0a7d106 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a8998c387bfe39b6ce6f6a02ed105476 = $(`&lt;div id=&quot;html_a8998c387bfe39b6ce6f6a02ed105476&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3&lt;/div&gt;`)[0];
#                 popup_975280a7a689d58f26e9629ca0a7d106.setContent(html_a8998c387bfe39b6ce6f6a02ed105476);
#
#
#
#         marker_9a472353d3ced6b54792bb02ab70905c.bindPopup(popup_975280a7a689d58f26e9629ca0a7d106)
#         ;
#
#
#
#
#             var marker_5c02e99510391e4666ac435cb2876539 = L.marker(
#                 [37.5676455, 126.96161],
#                 {}
#             ).addTo(map_ee44606614655d76b62cb6bf57f2b8c6);
#
#
#         var popup_15b40a5d45bdc6e93decd027635af1bb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e13b4f6d5f521ca854d0d39dccbcd243 = $(`&lt;div id=&quot;html_e13b4f6d5f521ca854d0d39dccbcd243&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4&lt;/div&gt;`)[0];
#                 popup_15b40a5d45bdc6e93decd027635af1bb.setContent(html_e13b4f6d5f521ca854d0d39dccbcd243);
#
#
#
#         marker_5c02e99510391e4666ac435cb2876539.bindPopup(popup_15b40a5d45bdc6e93decd027635af1bb)
#         ;
#
#
#
#
#             var marker_406451490ea195b8d7a56e15236ce1df = L.marker(
#                 [37.5407625, 127.0793428],
#                 {}

# %%
df.index
# Out:
# Index(['KAIST 서울캠퍼스 ', 'KC대학교', '가톨릭대학교(성신교정)', '가톨릭대학교(성의교정)', '감리교신학대학교',
#        '건국대학교', '경기대학교 서울캠퍼스 ', '경희대학교 서울캠퍼스 ', '고려대학교', '광운대학교', '국민대학교',
#        '덕성여자대학교', '동국대학교', '동덕여자대학교', '명지대학교 서울캠퍼스 ', '삼육대학교', '상명대학교 서울캠퍼스 ',
#        '서강대학교', '서경대학교', '서울과학기술대학교', '서울교육대학교', '서울기독대학교', '서울대학교', '서울시립대학교',
#        '서울여자대학교', '서울한영대학교', '성공회대학교', '성균관대학교 서울캠퍼스  ', '성신여자대학교', '세종대학교',
#        '숙명여자대학교', '숭실대학교', '연세대학교', '육군사관학교', '이화여자대학교', '장로회신학대학교',
#        '중앙대학교 서울캠퍼스 ', '총신대학교', '추계예술대학교', '한국방송통신대학교', '한국성서대학교', '한국예술종합학교',
#        '한국외국어대학교', '한국체육대학교', '한성대학교', '한양대학교', '홍익대학교'],
#       dtype='object', name='Unnamed: 0')

# %%
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ee44606614655d76b62cb6bf57f2b8c6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ee44606614655d76b62cb6bf57f2b8c6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ee44606614655d76b62cb6bf57f2b8c6 = L.map(
#                 &quot;map_ee44606614655d76b62cb6bf57f2b8c6&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_840a4bd8d0d4c6e8a128279e06dcd11a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_840a4bd8d0d4c6e8a128279e06dcd11a.addTo(map_ee44606614655d76b62cb6bf57f2b8c6);
#
#
#             tile_layer_840a4bd8d0d4c6e8a128279e06dcd11a.addTo(map_ee44606614655d76b62cb6bf57f2b8c6);
#
#
#             var marker_0a00b6df1ef5eff57cbf8a4342e47cee = L.marker(
#                 [37.592573, 127.046737],
#                 {}
#             ).addTo(map_ee44606614655d76b62cb6bf57f2b8c6);
#
#
#         var popup_6e9770f0bb2bc34d7e13b04ecf346cfd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_542d708fc5bc76a9a708e294c5d316bc = $(`&lt;div id=&quot;html_542d708fc5bc76a9a708e294c5d316bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0&lt;/div&gt;`)[0];
#                 popup_6e9770f0bb2bc34d7e13b04ecf346cfd.setContent(html_542d708fc5bc76a9a708e294c5d316bc);
#
#
#
#         marker_0a00b6df1ef5eff57cbf8a4342e47cee.bindPopup(popup_6e9770f0bb2bc34d7e13b04ecf346cfd)
#         ;
#
#
#
#
#             var marker_f3b63964f30c813d9ddc72b730d07ae9 = L.marker(
#                 [37.5483449, 126.8547974],
#                 {}
#             ).addTo(map_ee44606614655d76b62cb6bf57f2b8c6);
#
#
#         var popup_47da073a66a8692e2e30cf7eca514c68 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fff1e02d8c581aea16e6e5fe29fdb6f7 = $(`&lt;div id=&quot;html_fff1e02d8c581aea16e6e5fe29fdb6f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1&lt;/div&gt;`)[0];
#                 popup_47da073a66a8692e2e30cf7eca514c68.setContent(html_fff1e02d8c581aea16e6e5fe29fdb6f7);
#
#
#
#         marker_f3b63964f30c813d9ddc72b730d07ae9.bindPopup(popup_47da073a66a8692e2e30cf7eca514c68)
#         ;
#
#
#
#
#             var marker_cca5e128857f3dd2d64182f230f40bfa = L.marker(
#                 [37.5859218, 127.0043275],
#                 {}
#             ).addTo(map_ee44606614655d76b62cb6bf57f2b8c6);
#
#
#         var popup_7249c4727b7f95a8bd9670a4cd6d75d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0409218194d9820e25fa573da225ab89 = $(`&lt;div id=&quot;html_0409218194d9820e25fa573da225ab89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2&lt;/div&gt;`)[0];
#                 popup_7249c4727b7f95a8bd9670a4cd6d75d8.setContent(html_0409218194d9820e25fa573da225ab89);
#
#
#
#         marker_cca5e128857f3dd2d64182f230f40bfa.bindPopup(popup_7249c4727b7f95a8bd9670a4cd6d75d8)
#         ;
#
#
#
#
#             var marker_9a472353d3ced6b54792bb02ab70905c = L.marker(
#                 [37.4996227, 127.0060653],
#                 {}
#             ).addTo(map_ee44606614655d76b62cb6bf57f2b8c6);
#
#
#         var popup_975280a7a689d58f26e9629ca0a7d106 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a8998c387bfe39b6ce6f6a02ed105476 = $(`&lt;div id=&quot;html_a8998c387bfe39b6ce6f6a02ed105476&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3&lt;/div&gt;`)[0];
#                 popup_975280a7a689d58f26e9629ca0a7d106.setContent(html_a8998c387bfe39b6ce6f6a02ed105476);
#
#
#
#         marker_9a472353d3ced6b54792bb02ab70905c.bindPopup(popup_975280a7a689d58f26e9629ca0a7d106)
#         ;
#
#
#
#
#             var marker_5c02e99510391e4666ac435cb2876539 = L.marker(
#                 [37.5676455, 126.96161],
#                 {}
#             ).addTo(map_ee44606614655d76b62cb6bf57f2b8c6);
#
#
#         var popup_15b40a5d45bdc6e93decd027635af1bb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e13b4f6d5f521ca854d0d39dccbcd243 = $(`&lt;div id=&quot;html_e13b4f6d5f521ca854d0d39dccbcd243&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4&lt;/div&gt;`)[0];
#                 popup_15b40a5d45bdc6e93decd027635af1bb.setContent(html_e13b4f6d5f521ca854d0d39dccbcd243);
#
#
#
#         marker_5c02e99510391e4666ac435cb2876539.bindPopup(popup_15b40a5d45bdc6e93decd027635af1bb)
#         ;
#
#
#
#
#             var marker_406451490ea195b8d7a56e15236ce1df = L.marker(
#                 [37.5407625, 127.0793428],
#                 {}

# %% [markdown]
# ### IFrame popup
